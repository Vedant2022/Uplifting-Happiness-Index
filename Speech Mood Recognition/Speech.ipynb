# %%
import librosa
import soundfile
import os, glob, pickle
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score

# %%
#DataFlair - Extract features (mfcc, chroma, mel) from a sound file
def extract_feature(file_name, mfcc, chroma, mel):
    with soundfile.SoundFile(file_name) as sound_file:
        X = sound_file.read(dtype="float32")
        sample_rate=sound_file.samplerate
        if chroma:
            stft=np.abs(librosa.stft(X))
        result=np.array([])
        if mfcc:
            mfccs=np.mean(librosa.feature.mfcc(y=X, sr=sample_rate, n_mfcc=40).T, axis=0)
            result=np.hstack((result, mfccs))
        if chroma:
            chroma=np.mean(librosa.feature.chroma_stft(S=stft, sr=sample_rate).T,axis=0)
            result=np.hstack((result, chroma))
        if mel:
            mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
            result=np.hstack((result, mel))
        return result

# %%
#DataFlair - Emotions in the RAVDESS dataset
emotions={
  '01':'neutral',
  '02':'calm',
  '03':'happy',
  '04':'sad',
  '05':'angry',
  '06':'fearful',
  '07':'disgust',
  '08':'surprised'
}

#DataFlair - Emotions to observe
observed_emotions=['calm', 'happy', 'fearful', 'disgust']

# %%
#DataFlair - Load the data and extract features for each sound file
def load_data(test_size=0.2):
    x,y=[],[]
    # D:\\DataFlair\\ravdess data\\Actor_*\\*.wav
    for file in glob.glob("F:\\Speech\\Actor_*\\*.wav"):
        file_name=os.path.basename(file)
        emotion=emotions[file_name.split("-")[2]]
        if emotion not in observed_emotions:
            continue
        feature=extract_feature(file, mfcc=True, chroma=True, mel=True)
        x.append(feature)
        y.append(emotion)
    return train_test_split(np.array(x), y, test_size=test_size, random_state=9)

# %%
#DataFlair - Split the dataset
x_train,x_test,y_train,y_test=load_data(test_size=0.2)
# Out:
# C:\Users\salun\AppData\Local\Temp\ipykernel_7280\3018817742.py:16: FutureWarning: Pass y=[0. 0. 0. ... 0. 0. 0.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# C:\Users\salun\AppData\Local\Temp\ipykernel_7280\3018817742.py:16: FutureWarning: Pass y=[0.0000000e+00 3.0517578e-05 3.0517578e-05 ... 0.0000000e+00 0.0000000e+00
#  0.0000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# C:\Users\salun\AppData\Local\Temp\ipykernel_7280\3018817742.py:16: FutureWarning: Pass y=[ 0.0000000e+00  0.0000000e+00 -3.0517578e-05 ... -3.0517578e-05
#  -3.0517578e-05 -3.0517578e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
# ...

# %%
#DataFlair - Get the shape of the training and testing datasets
print((x_train.shape[0], x_test.shape[0]))
# Out:
# (614, 154)

# %%
#DataFlair - Get the number of features extracted
print(f'Features extracted: {x_train.shape[1]}')
# Out:
# Features extracted: 180

# %%
#DataFlair - Initialize the Multi Layer Perceptron Classifier
model=MLPClassifier(alpha=0.02, batch_size=128, epsilon=1e-06, hidden_layer_sizes=(250,), learning_rate='adaptive', max_iter=800)

# %%
#DataFlair - Train the model
model.fit(x_train,y_train)
# Out:
# MLPClassifier(alpha=0.02, batch_size=128, epsilon=1e-06,
#               hidden_layer_sizes=(250,), learning_rate='adaptive',
#               max_iter=800)

# %%
#DataFlair - Predict for the test set
y_pred=model.predict(x_test)
y_pred
# Out:
# array(['happy', 'fearful', 'happy', 'happy', 'disgust', 'disgust',
#        'disgust', 'disgust', 'disgust', 'fearful', 'happy', 'fearful',
#        'fearful', 'happy', 'disgust', 'happy', 'calm', 'disgust',
#        'disgust', 'disgust', 'disgust', 'disgust', 'disgust', 'disgust',
#        'fearful', 'happy', 'happy', 'happy', 'fearful', 'fearful',
#        'happy', 'disgust', 'happy', 'fearful', 'disgust', 'calm', 'calm',
#        'fearful', 'calm', 'disgust', 'happy', 'disgust', 'calm', 'calm',
#        'fearful', 'disgust', 'disgust', 'happy', 'calm', 'happy',
#        'fearful', 'fearful', 'fearful', 'happy', 'happy', 'fearful',
#        'disgust', 'happy', 'calm', 'calm', 'disgust', 'calm', 'disgust',
#        'calm', 'disgust', 'calm', 'calm', 'disgust', 'disgust', 'happy',
#        'fearful', 'fearful', 'fearful', 'fearful', 'fearful', 'disgust',
#        'fearful', 'happy', 'fearful', 'fearful', 'disgust', 'calm',
# ...

# %%
#DataFlair - Calculate the accuracy of our model
accuracy=accuracy_score(y_true=y_test, y_pred=y_pred)

#DataFlair - Print the accuracy
print("Accuracy: {:.2f}%".format(accuracy*100))
# Out:
# Accuracy: 70.13%

# %%
#DataFlair - Load the data and extract features for each sound file
def load_data_new(file_name):
    x,y=[],[]
    # D:\\DataFlair\\ravdess data\\Actor_*\\*.wav
    # for file in glob.glob("F:\\Speech\\Actor_*\\*.wav"):
    file = "F:\\{}.wav".format(file_name)
    file_name=os.path.basename(file)
    emotion=emotions[file_name.split("-")[2]]
    if emotion not in observed_emotions:
        pass
    feature=extract_feature(file, mfcc=True, chroma=True, mel=True)
    x.append(feature)
    y.append(emotion)
    return np.array(x), y

# %%
file_name = input('Enter the File name: ')
data, emotion = load_data_new(file_name=file_name)
data.shape
# Out:
# C:\Users\salun\AppData\Local\Temp\ipykernel_10900\3018817742.py:16: FutureWarning: Pass y=[0. 0. 0. ... 0. 0. 0.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# (1, 180)

# %%
result = model.predict(data)[0]

# %%
print('Emotion of Speech is {}'.format(result))
# Out:
# Emotion of Speech is happy

# %%
import pickle
pickle.dump(model, open('model.pkl', 'wb'))

# %%
import speech_recognition as sr
import pyttsx3

"""The main speaking engine is here"""
engine = pyttsx3.init()
voices = engine.getProperty("voices")
engine.setProperty("voice", voices[0].id)
rate = engine.getProperty("rate")
engine.setProperty("rate", rate - 50)

def speak(audio):
    """It is used to speak the audio output"""
    engine.say(audio)
    engine.runAndWait()

def Take_Command():
    """It simply take command from the user"""
    r = sr.Recognizer()
    with sr.Microphone() as source:
        print("\nListening...")
        r.pause_threshold = 0.5
        r.energy_threshold = 500
        audio = r.listen(source)
        print(audio)
        engine.save_to_file(audio, 'speech.mp3')
    try:
        print("Recognizing...")
        query = r.recognize_google(audio, language="en-in")
    except Exception as error:
        print(f"This is the error: {error}")
        print("Please speak clearly...")
        speak("Please speak clearly...")
        return "None"
    return query

# %%
speak("Hello Friendn")

# %%
query = Take_Command()
engine.save_to_file(query, 'F:\\speech.wav')
# Out:
# Listening...
# ...
# Recognizing...

# %%
query
# Out:
# 'hello my name is Vikram Thakor na kari'

# %%
import sounddevice as sd
from scipy.io.wavfile import write

fs = 44100  # Sample rate
seconds = 4  # Duration of recording

myrecording = sd.rec(int(seconds * fs), samplerate=fs, channels=2)
sd.wait()  # Wait until recording is finished
write('output.wav', fs, myrecording)  # Save as WAV file

# %%
pickled_model = pickle.load(open('model.pkl', 'rb'))
pickled_model.predict(load_data_new(file_name='output')[0])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In [20], line 2
#       1 pickled_model = pickle.load(open('model.pkl', 'rb'))
# ----> 2 pickled_model.predict(load_data_new(file_name='output')[0])
#
# Cell In [16], line 8, in load_data_new(file_name)
#       6 file = "F:\\{}.wav".format(file_name)
#       7 file_name=os.path.basename(file)
# ----> 8 emotion=emotions[file_name.split("-")[2]]
#       9 if emotion not in observed_emotions:
#      10     pass
#
# IndexError: list index out of range
